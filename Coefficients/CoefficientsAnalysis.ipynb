# %%
# -*- coding: utf-8 -*-
## Imports
import pandas as pd
import matplotlib.pyplot as plt
import time
import CoefficientsGenerator as gc

# %%
def generate_histogram_coef(csv_file, range_start, range_end, interval, coef_degree,poly_degree = 4):
    """
    Generates a histogram of the coefficients of a polynomial generates in a random way.
    Input:
        csv_file: csv file with the coefficients
        range_start: minimum value of the range
        range_end: maximum value of the range
        interval: interval of the range
        coef_degree: degree of the polynomial
        poly_degree: degree of the polynomial
    Output:
        histogram of the coefficients
    """
    
    # Read the CSV file into a Pandas DataFrame with a default column name
    df = pd.read_csv(csv_file, header=None, names=['Value'])

    # Extract the single column
    data = df['Value']
    
    # Print the minimum and maximum values
    min_value = data.min()
    max_value = data.max()
    print(f"Minimum Value: {min_value}")
    print(f"Maximum Value: {max_value}")

    # Create a histogram
    plt.hist(data, bins=range(range_start, range_end + interval, interval), color='black', edgecolor='black')
    
    # Customize the plot
    plt.title(f'Histogram of coefficients with degree {coef_degree}')
    plt.xlabel('coefficients')
    plt.ylabel('Frequency')

    # Show the plot
    plt.show()

# %%
# Example usage:
ranges = [[-30,30],[-100,300],[-1000,1000]]
for i in range(0,3):
    csv_file_path = f'coef_{i+1}.csv'  # Replace with the path to your CSV file
    range_start = ranges[i][0]
    range_end = ranges[i][1]
    interval = 1
    generate_histogram_coef(csv_file_path, range_start, range_end, interval,i+1,4)
# Out:
# Minimum Value: -29.885414924075704
# Maximum Value: 29.81763144034376
# Minimum Value: -99.958493898615
# Maximum Value: 297.70936840682134
# Minimum Value: -990.7483409091534
# Maximum Value: 992.68176461181

# %%
start = time.time()
generator = gc.CoefficientsGenerator()
end = time.time()
print(f"Time elapsed of loading the database: {end - start} seconds")


start = time.time()
for i in range(100):
    coefficients = generator.generate()
    print(coefficients)
end = time.time()
print(f"Time elapsed of generate 100 sets of coefficients: {end - start} seconds")
# Out:
# Time elapsed of loading the database: 22.25770378112793 seconds
# [1, -2.916745577252348, 23.99662974331386, 28.255784132361743, 0]
# [1, -6.771827916591397, -1.969923026738534, 114.35271508701148, 0]
# [1, -2.569872756197354, -55.78315068013234, -80.68188938587026, 0]
# [1, 20.543834303747914, -5.085280876612298, -174.5898149878112, 0]
# [1, 9.89415713989193, 96.96251885507058, 19.56497899086532, 0]
# [1, -8.963381541861533, 13.91534209623259, 132.07195337260026, 0]
# [1, -6.213361393013205, 43.820388380372464, 223.18740734463572, 0]
# [1, 0.7310950962570768, -84.5372616531255, 219.1977940359164, 0]
# [1, 0.19076773986263795, -41.128030624272974, -12.669067114299343, 0]
# [1, -0.33787821406954066, -70.64342958420832, -12.31933550299729, 0]
# [1, 9.999783082647447, 10.521898734250541, 312.3607111897069, 0]
# [1, -8.312696591115964, 22.607837754471095, -1.773980327392472, 0]
# [1, 13.978360977935129, 31.348327549588205, 24.745990463319743, 0]
# [1, -11.86671842279517, -12.594262024039303, 274.9135440246935, 0]
# [1, -0.4843553837518666, -1.672219229570861, -84.9678540049699, 0]
# [1, -18.452540146696293, -22.54180731732729, -90.216816335752, 0]
# [1, -3.486722236682926, 3.95154084191776, -24.594170432102548, 0]
# [1, 5.843761728748637, -34.40550940932344, 117.36389344702661, 0]
# [1, 14.715521211708218, -63.19154444248713, -117.34282276084896, 0]
# [1, 10.139793571705974, 13.206564727694111, -5.95218206023188, 0]
# [1, 0.533886123950241, 7.235097433492194, 59.176540308982254, 0]
# [1, 8.38247542406008, 77.08611877233565, 23.72642596036955, 0]
# [1, -13.057702462041227, -21.31237282940234, 306.050681487483, 0]
# [1, -2.938628138762814, -30.163023912674745, -1.0852768541641282, 0]
# [1, -13.878452086427007, -65.90973955450369, -354.15618003549446, 0]
# [1, -0.3856580138824448, 50.550794548113174, 84.77306509298165, 0]
# [1, -11.6978418041101, 86.76251723404616, 132.0710217175708, 0]
# [1, 9.2313868437418, 50.322302061901844, -330.191272970725, 0]
# [1, 3.122668543181236, 15.48413718477194, 37.273101208952156, 0]
# [1, 13.806662357806147, 73.41788015551097, 119.62048826356757, 0]
# [1, 4.800359766491285, -21.887591046441205, 34.60889377321494, 0]
# [1, -18.77671995351958, -31.510590594874245, 7.273251942464352, 0]
# [1, -16.449758288517252, -49.61366994208747, -209.2336244295123, 0]
# [1, 0.01870877399143467, -15.643356521010801, 52.93856286378326, 0]
# [1, -10.251783161301582, 13.738075343920265, 241.6171130751903, 0]
# [1, 4.265483349238144, -4.9139153516047545, -23.339715385485277, 0]
# [1, 15.185276355878894, 41.13228749859623, -7.8076881626840535, 0]
# [1, 3.7261858907937793, 24.41387816382677, -50.76280624949194, 0]
# [1, -7.20491383904873, 29.20624482314665, -126.04892015020185, 0]
# [1, 0.24625520340884677, 21.900201605829153, -96.58524795951072, 0]
# [1, -3.1792542123861818, 7.560894412398391, -190.25688450914225, 0]
# [1, 0.880638440528454, 90.06626869463584, -263.9013735364665, 0]
# [1, 16.232066344009276, 142.4617468274744, -0.3023313316655166, 0]
# [1, 15.099553681589814, 104.52250876314018, -3.949259260737601, 0]
# [1, -3.2394806184832943, -41.04289134616975, 434.34415632104145, 0]
# [1, 16.73681009006347, -26.692246405210433, -7.199546773518999, 0]
# [1, -7.536563122336506, 76.98472536510275, -1.8869595478581476, 0]
# [1, -7.852186003833408, -4.503577633480053, 66.64911232144739, 0]
# [1, 4.847863837671967, 27.223984753814236, 255.07853143774724, 0]
# [1, 2.702544043226002, -77.85435118603348, 104.25954696802751, 0]
# [1, -3.7106991089151204, -46.20146253000211, -21.353244475924782, 0]
# [1, 1.060859928048199, -51.05094392015892, -17.332933835007243, 0]
# [1, -1.1428350358747794, 9.93780296657459, 38.8602942220707, 0]
# [1, 16.236909961781045, -62.69067878880772, 81.13054815343375, 0]
# [1, -18.290144987259005, 45.03087838728476, 47.7345852129115, 0]
# [1, 2.085156574380841, 66.49998764097086, 190.31524885978578, 0]
# [1, -5.091457501515492, -53.2513813143285, -68.84254944749526, 0]
# [1, -5.541659316081482, 41.14889641205707, -97.46137744026119, 0]
# [1, -8.177087509089867, -0.06183543379113754, -46.86120408388681, 0]
# [1, 7.0518159572576025, -18.29955000209874, -76.2605451236101, 0]
# [1, -4.558185301526178, -62.043137240485756, -19.096655450240398, 0]
# [1, 11.089881152582349, -2.302883496003206, 0.42980895913114275, 0]
# [1, 8.271705017603484, -41.70360131843656, -36.49541674986369, 0]
# [1, -0.2020636876400701, -50.15123461571579, 4.609650449245244, 0]
# [1, 3.9776467081189537, -14.493208802524727, 1.7607313157610747, 0]
# [1, -11.670196204960531, 162.7864090598263, 111.72349561364584, 0]
# [1, 8.296588185589611, -2.0324868459535717, 109.25671529545212, 0]
# [1, -11.055099629686008, 128.65320803409975, -115.38786402741613, 0]
# [1, -4.6106412718845835, 84.77053049121683, 25.772594641598463, 0]
# [1, 15.14334842151844, 1.1941725211115966, 256.8824972541048, 0]
# [1, 2.198726219798056, 55.66824777174597, -78.49449866003594, 0]
# [1, 0.11229640950306319, -9.103927401862554, -51.83807900698751, 0]
# [1, 23.47889656784831, 8.108918666001038, 328.345291143473, 0]
# [1, 5.012037264286883, -69.72967166809211, 35.74330642229545, 0]
# [1, -6.37958114394096, -38.141381511055314, 212.86997412524258, 0]
# [1, 14.12343561783771, -3.993896556188383, 95.70814051491381, 0]
# [1, -9.197156439053556, -2.5202315781168814, -40.2586782954848, 0]
# [1, -0.1915338353778111, 25.95943140068309, -33.14046750656111, 0]
# [1, 7.665677134498578, 24.824315502966883, -197.75830311340394, 0]
# [1, 3.659251547903854, 104.74867509000975, -17.76834821373214, 0]
# [1, -9.885812477980028, -62.85738410047408, 439.16055548591635, 0]
# [1, 7.231164795955188, -65.51427839844916, -34.42821109702151, 0]
# [1, 5.745107879287286, 108.77208446313173, -257.40260149764896, 0]
# [1, -15.12642100261245, -14.970325293606695, -95.34173050150721, 0]
# [1, -9.14134880323166, 56.581794321872835, 437.4644920330174, 0]
# [1, 19.53727412507311, -3.0615876216734748, 182.99785810777652, 0]
# [1, -14.75123670413458, -5.23522291220425, 50.35608936018175, 0]
# [1, 6.649871967957473, -1.9230356811493443, -19.967885757914658, 0]
# [1, 9.787543272542262, 67.0396246058012, -6.4536877424909145, 0]
# [1, -9.921130266863145, -21.657004472942802, 384.72994183840814, 0]
# [1, 0.8361777010050089, -64.93023985328948, -343.8990183115502, 0]
# [1, 3.720790294997122, -14.169272227443633, -2.1855185649275213, 0]
# [1, -8.508922588860186, -22.341920208157266, 152.18214186690315, 0]
# [1, -4.564974405320621, -35.73132970685955, -13.03009541469553, 0]
# [1, 12.144080795092263, 108.9034257117204, -19.10622837525287, 0]
# [1, 2.0350380629486677, -29.05083959838016, -7.114770329740557, 0]
# [1, 3.5118230995806314, 74.12676676567247, -125.31010141418687, 0]
# [1, -2.382625297514524, -29.50699470636563, -35.01856603261663, 0]
# [1, -3.915532618205175, -77.74642511441034, 15.762585444670378, 0]
# [1, 14.449794996681097, -1.972245898695409, 79.3168202516219, 0]
# Time elapsed of generate 100 sets of coefficients: 0.001111745834350586 seconds
